# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.9.0'

# %%
import numpy as np

# %%
 from tensorflow import keras
 import matplotlib.pyplot as plt

# %%
 fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.gca().grid(True)

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
# Out:
# /home/siwan/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer=tf.train.AdamOptimizer(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.4916 - acc: 0.8274
# Epoch 2/5
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.3727 - acc: 0.8659
# Epoch 3/5
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.3343 - acc: 0.8778
# Epoch 4/5
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.3104 - acc: 0.8859
# Epoch 5/5
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.2922 - acc: 0.8914

# %%
model.fit(train_images, train_labels, epochs=7)
# Out:
# Epoch 1/7
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.2797 - acc: 0.8948
# Epoch 2/7
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2673 - acc: 0.9016
# Epoch 3/7
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.2567 - acc: 0.9047
# Epoch 4/7
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2460 - acc: 0.9083
# Epoch 5/7
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2383 - acc: 0.9113
# Epoch 6/7
# 60000/60000 [==============================] - 5s 86us/step - loss: 0.2285 - acc: 0.9147
# Epoch 7/7
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.2234 - acc: 0.9153

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test_accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 44us/step
# test_accuracy: 0.8887

# %%
predictions= model.predict(test_images)
predictions[0]
# Out:
# array([1.09469966e-07, 2.02377601e-14, 8.71838046e-10, 1.13155570e-11,
#        1.79257997e-10, 9.58116609e-04, 3.69410600e-08, 1.91267300e-02,
#        7.39928208e-09, 9.79914963e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
plt.figure(figsize=(10,10))

for i in range (25):
    plt.subplot(5,5, 1+i)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    predictions_labels=np.argmax(predictions[i])
    true_labels= test_labels[i]
    if predictions_labels==true_labels :
        color = 'green'
    else:
            color  = 'red'
    plt.xlabel("{},({})".format( class_names[predictions_labels],class_names[true_labels]), color=color)
# Out:
# /home/siwan/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
